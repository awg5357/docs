# %% [markdown]
# <a href="https://colab.research.google.com/github/awg5357/docs/blob/master/Basic%20Image%20Manipulation%20(Histograms).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from PIL import Image, ImageOps

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.1.0

# %%
img = plt.imread('/content/sample_data/small_images/f022-001-9780323354790.jpeg')
plt.imshow(img)

# %%
img.shape
# Out:
# (2329, 2086, 3)

# %%
im = Image.fromarray(np.uint8(img))
im = ImageOps.equalize(im)
plt.imshow(im)

# %%
img2 = np.asarray(im)
plt.imshow(img2)

# %%
plt.hist(img.ravel())
# Out:
# (array([  127813.,   224640.,    52272.,   188868.,    67044.,    69589.,
#          1009144.,   521254.,  1226666., 11087592.]),
#  array([  7. ,  31.8,  56.6,  81.4, 106.2, 131. , 155.8, 180.6, 205.4,
#         230.2, 255. ]),
#  <a list of 10 Patch objects>)

# %%
img2 = plt.imread('/content/sample_data/small_images/f022-002-9780323354790.jpeg')
plt.imshow(img2)

# %%
img2.shape
# Out:
# (2123, 2739, 3)

# %%
im = Image.fromarray(np.uint8(img2))
im = ImageOps.equalize(im)
plt.imshow(im)

# %%
img2 = np.asarray(im)
plt.imshow(img2)

# %%
plt.hist(img2.ravel())
# Out:
# (array([  506207.,   581220.,   479019.,  1223579.,  1538519.,        0.,
#                0.,        0.,   243038., 12873109.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
img3 = plt.imread('/content/sample_data/small_images/f003-002-9780323354790.jpeg')
plt.imshow(img)

# %%
img3.shape
im3 = Image.fromarray(np.uint8(img3))
im3 = ImageOps.equalize(im3)
plt.imshow(im3)

# %%
img3 = np.asarray(im3)
plt.imshow(img3)

# %%
plt.hist(img3.ravel())
# Out:
# (array([ 103392.,  102374.,  116493.,  106994.,   92174.,  147780.,
#           60008.,  131854.,   78640., 2370473.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)
